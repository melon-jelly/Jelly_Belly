# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import platform


dat_top10 = pd.read_csv('coronaboard_0623_today_top10.csv')

dat_top10.head()
# Out:
#         국가  치명(%)  완치(%)    발생률         인구수    확진자_합계    확진자1일   치료중_합계  \
# 0    브라질🇧🇷    2.8   90.8  84949   212559417  18056639  86833.0  1162895
# 1   콜롬비아🇨🇴    2.5   92.9  78553    50882891   3997021  28616.0   180757
# 2     인도🇮🇳    1.3   96.6  21760  1380004385  30028709  26018.0   643163
# 3  아르헨티나🇦🇷    2.1   91.4  95115    45195774   4298782  21387.0   280112
# 4    러시아🇷🇺    2.4   91.3  36787   145934462   5368513  17594.0   335508
#
#    치료중1일  위중증_합계  위중증1일   사망자합계  사망자1일      완치합계    완치1일
# 0 -15702  8318.0    NaN  504897   2080  16388847  100455
# 1  -1119  8155.0    NaN  101302    720   3714962   29015
# 2 -19141  8944.0    NaN  390691   1030  28994855   44129
# 3   3042  7345.0    NaN   90281    791   3928389   17554
# 4   4386  2300.0    NaN  130895    548   4902110   12660

# %%
dat_top10['국가'] = dat_top10['국가'].str[:-2]
dat_top10.head()
# Out:
#       국가  치명(%)  완치(%)    발생률         인구수    확진자_합계    확진자1일   치료중_합계  치료중1일  \
# 0    브라질    2.8   90.8  84949   212559417  18056639  86833.0  1162895 -15702
# 1   콜롬비아    2.5   92.9  78553    50882891   3997021  28616.0   180757  -1119
# 2     인도    1.3   96.6  21760  1380004385  30028709  26018.0   643163 -19141
# 3  아르헨티나    2.1   91.4  95115    45195774   4298782  21387.0   280112   3042
# 4    러시아    2.4   91.3  36787   145934462   5368513  17594.0   335508   4386
#
#    위중증_합계  위중증1일   사망자합계  사망자1일      완치합계    완치1일
# 0  8318.0    NaN  504897   2080  16388847  100455
# 1  8155.0    NaN  101302    720   3714962   29015
# 2  8944.0    NaN  390691   1030  28994855   44129
# 3  7345.0    NaN   90281    791   3928389   17554
# 4  2300.0    NaN  130895    548   4902110   12660

# %%
import os, warnings
warnings.filterwarnings(action='ignore')

# %%
if platform.system()=='Windows':
    plt.rc('font',family= 'Malgun Gothic')
fig = plt.figure(figsize=(15,10))
sns.barplot(data=dat_top10 , x='국가', y='확진자1일')
plt.show()

# %% [markdown]
# ## CPI

# %%
CPI = pd.read_csv('CPI2020_GlobalTablesTS_210125.csv')
CPI
# Out:
#     Corruption Perceptions Index 2020: Global Scores  Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                             Country       ISO3     Region
# 2                                             Denmark        DNK      WE/EU
# 3                                         New Zealand        NZL         AP
# 4                                             Finland        FIN      WE/EU
# ..                                                ...        ...        ...
# 177                                         Venezuela        VEN        AME
# 178                                             Yemen        YEM       MENA
# 179                                             Syria        SYR       MENA
# 180                                           Somalia        SOM        SSA
# 181                                       South Sudan        SSD        SSA
#
# ...

# %%
CPI = CPI.iloc[:,[0,1,3]]
CPI.columns = ['Country','ISO3','CPI score 2020']
CPI = CPI.drop(CPI.index[0:2])

# %%
CPI
# Out:
#          Country ISO3 CPI score 2020
# 2        Denmark  DNK             88
# 3    New Zealand  NZL             88
# 4        Finland  FIN             85
# 5      Singapore  SGP             85
# 6         Sweden  SWE             85
# ..           ...  ...            ...
# 177    Venezuela  VEN             15
# 178        Yemen  YEM             15
# 179        Syria  SYR             14
# 180      Somalia  SOM             12
# 181  South Sudan  SSD             12
#
# [180 rows x 3 columns]

# %% [markdown]
# ## 1000명당 의사 수 데이터

# %%
doc = pd.read_csv('OECD_num_of_doctors_per1000.csv')
doc.head()
# Out:
#   LOCATION   INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 0      AUS  MEDICALDOC     TOT  1000HAB         A  1961   1.13        NaN
# 1      AUS  MEDICALDOC     TOT  1000HAB         A  1964   1.23        NaN
# 2      AUS  MEDICALDOC     TOT  1000HAB         A  1965   1.22        NaN
# 3      AUS  MEDICALDOC     TOT  1000HAB         A  1966   1.23        NaN
# 4      AUS  MEDICALDOC     TOT  1000HAB         A  1967   1.26        NaN

# %%
doc2018.head()
# Out:
#     LOCATION   INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 54       AUS  MEDICALDOC     TOT  1000HAB         A  2018   3.75          E
# 113      AUT  MEDICALDOC     TOT  1000HAB         A  2018   5.24        NaN
# 171      BEL  MEDICALDOC     TOT  1000HAB         A  2018   3.13        NaN
# 229      CAN  MEDICALDOC     TOT  1000HAB         A  2018   2.78        NaN
# 275      CZE  MEDICALDOC     TOT  1000HAB         A  2018   4.04        NaN

# %%
mask1 = (doc.TIME == 2018)
doc2018 = doc.loc[mask1,:]
doc2018.head()
# Out:
#     LOCATION   INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 54       AUS  MEDICALDOC     TOT  1000HAB         A  2018   3.75          E
# 113      AUT  MEDICALDOC     TOT  1000HAB         A  2018   5.24        NaN
# 171      BEL  MEDICALDOC     TOT  1000HAB         A  2018   3.13        NaN
# 229      CAN  MEDICALDOC     TOT  1000HAB         A  2018   2.78        NaN
# 275      CZE  MEDICALDOC     TOT  1000HAB         A  2018   4.04        NaN

# %%
doc2018.rename(columns={'LOCATION':'ISO3'},inplace=True)
doc2018.head()
# Out:
#     ISO3   INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 54   AUS  MEDICALDOC     TOT  1000HAB         A  2018   3.75          E
# 113  AUT  MEDICALDOC     TOT  1000HAB         A  2018   5.24        NaN
# 171  BEL  MEDICALDOC     TOT  1000HAB         A  2018   3.13        NaN
# 229  CAN  MEDICALDOC     TOT  1000HAB         A  2018   2.78        NaN
# 275  CZE  MEDICALDOC     TOT  1000HAB         A  2018   4.04        NaN

# %% [markdown]
# ## 1000명당 간호사 수

# %%
nur = pd.read_csv('OECD_num_of_nurses_per1000.csv')
nur.head()
# Out:
#   LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 0      AUS     NURSE     TOT  1000HAB         A  1980  10.33        NaN
# 1      AUS     NURSE     TOT  1000HAB         A  1981   9.91        NaN
# 2      AUS     NURSE     TOT  1000HAB         A  1982   9.85        NaN
# 3      AUS     NURSE     TOT  1000HAB         A  1983   9.87        NaN
# 4      AUS     NURSE     TOT  1000HAB         A  1984   9.91        NaN

# %%
mask1 = (nur.TIME == 2018)
nur2018 = nur.loc[mask1,:]
nur2018.head()
# Out:
#     LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 36       AUS     NURSE     TOT  1000HAB         A  2018  11.92          E
# 70       AUT     NURSE     TOT  1000HAB         A  2018   6.87          D
# 86       CAN     NURSE     TOT  1000HAB         A  2018   9.95        NaN
# 125      CZE     NURSE     TOT  1000HAB         A  2018   8.07        NaN
# 152      DNK     NURSE     TOT  1000HAB         A  2018  10.10        NaN

# %%
nur2018.rename(columns={'LOCATION':'ISO3'},inplace=True)
nur2018.head()
# Out:
#     ISO3 INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 36   AUS     NURSE     TOT  1000HAB         A  2018  11.92          E
# 70   AUT     NURSE     TOT  1000HAB         A  2018   6.87          D
# 86   CAN     NURSE     TOT  1000HAB         A  2018   9.95        NaN
# 125  CZE     NURSE     TOT  1000HAB         A  2018   8.07        NaN
# 152  DNK     NURSE     TOT  1000HAB         A  2018  10.10        NaN

# %% [markdown]
# ## 코로나19 전세계 6월22일 데이터

# %%
corona0622 = pd.read_csv('coronaboard_0623_yesterday.csv')
corona0622.head()
# Out:
#       국가 치명(%)  완치(%)     발생률         인구수    확진자_합계    확진자1일     치료중_합계  \
# 0   미국🇺🇸   1.8   83.6  104032   331002651  34419981  13922.0  5034090.0
# 1   인도🇮🇳   1.3   96.5   21760  1380004385  30002691  37399.0   662304.0
# 2  브라질🇧🇷   2.8   90.6   84949   212559417  17969806  41878.0  1178597.0
# 3  프랑스🇫🇷   1.9   96.7   88244    65273511   5757798    487.0    80626.0
# 4   터키🇹🇷   0.9   97.4   63811    84339067   5375593   5294.0    88626.0
#
#      치료중1일  위중증_합계  위중증1일   사망자합계  사망자1일        완치합계     완치1일
# 0 -43487.0  3939.0  -18.0  617483  317.0  28768408.0  57092.0
# 1 -18984.0  8944.0    NaN  389661  833.0  28950726.0  55550.0
# 2 -27175.0  8318.0    NaN  502817  899.0  16288392.0  68154.0
# 3  -9361.0  1655.0  -48.0  110778   40.0   5566394.0   9808.0
# 4    150.0   808.0   -5.0   49236   51.0   5237731.0   5093.0

# %%
import pandas as pd
import flag
import re

dat = corona0622
countries = dat['국가']

country_list = []
for country in countries:
    country = flag.dflagize(country).replace(':','')
    country = re.findall('[A-Z]{2}',country)
    if country == []:
        country = ['NA']
    country_list.append(country[0])
    
country_list
# Out:
# ['US',
#  'IN',
#  'BR',
#  'FR',
#  'TR',
#  'RU',
#  'GB',
#  'AR',
#  'IT',
#  'CO',
#  'ES',
#  'DE',
#  'IR',
#  'PL',
#  'MX',
#  'UA',
#  'PE',
#  'ID',
#  'ZA',
#  'NL',
#  'CZ',
#  'CL',
#  'CA',
#  'PH',
#  'IQ',
#  'SE',
#  'RO',
#  'BE',
#  'PK',
#  'PT',
#  'BD',
#  'IL',
#  'HU',
#  'JP',
#  'JO',
#  'RS',
#  'MY',
#  'CH',
#  'AT',
#  'NP',
#  'AE',
#  'LB',
#  'MA',
#  'SA',
#  'EC',
#  'BO',
#  'BG',
#  'GR',
#  'BY',
#  'KZ',
#  'PY',
#  'PA',
#  'SK',
#  'TN',
#  'GE',
#  'HR',
#  'UY',
#  'CR',
#  'KW',
#  'AZ',
#  'DO',
#  'PS',
#  'DK',
#  'GT',
#  'LT',
#  'EG',
#  'ET',
#  'IE',
#  'BH',
#  'VE',
#  'SI',
#  'MD',
#  'HN',
#  'OM',
#  'LK',
#  'TH',
#  'AM',
#  'QA',
#  'BA',
#  'LY',
#  'KE',
#  'CU',
#  'NG',
#  'MK',
#  'KR',
#  'MM',
#  'LV',
#  'DZ',
#  'ZM',
#  'AL',
#  'EE',
#  'NO',
#  'KG',
#  'AF',
#  'XK',
#  'UZ',
#  'ME',
#  'MN',
#  'GH',
#  'FI',
#  'CN',
#  'CM',
#  'SV',
#  'NA',
#  'CY',
#  'UG',
#  'MZ',
#  'MV',
#  'LU',
#  'BW',
#  'SG',
# ...

# %%
iso3 = []
for country in country_list:
    try:
        iso3.append(pycountry.countries.get(alpha_2='{}'.format(country)).alpha_3)
    except:
        iso3.append('NA')
len(iso3)
# Out:
# 221

# %%
corona0622.insert(1,"ISO3",iso3,True)
corona0622
# Out:
#            국가 ISO3 치명(%)  완치(%)     발생률         인구수    확진자_합계    확진자1일  \
# 0        미국🇺🇸  USA   1.8   83.6  104032   331002651  34419981  13922.0
# 1        인도🇮🇳  IND   1.3   96.5   21760  1380004385  30002691  37399.0
# 2       브라질🇧🇷  BRA   2.8   90.6   84949   212559417  17969806  41878.0
# 3       프랑스🇫🇷  FRA   1.9   96.7   88244    65273511   5757798    487.0
# 4        터키🇹🇷  TUR   0.9   97.4   63811    84339067   5375593   5294.0
# ..        ...  ...   ...    ...     ...         ...       ...      ...
# 216   마셜 제도🇲🇭  MHL     -  100.0      68       59190         4      NaN
# 217    바누아투🇻🇺  VUT    25   75.0      13      307145         4      NaN
# 218     사모아🇼🇸  WSM     -  100.0      15      198414         3      NaN
# 219  세인트헬레나🇸🇭  SHN     -  100.0     329        6077         2      NaN
# 220  미크로네시아🇫🇲  FSM     -  100.0       9      115023         1      NaN
#
#         치료중_합계    치료중1일  위중증_합계  위중증1일   사망자합계  사망자1일        완치합계     완치1일
# ...

# %% [markdown]
# ## ISO3을 통해 데이터 결합하기

# %% [markdown]
# #### merge를 이용해서 의사 수 데이터와 결합해보기

# %%
#예시 코드
import pandas as pd

df1 = pd.DataFrame({
        'Security': ['ABC', 'DEF', 'JHK', 'LMN', 'OPQ'],
        'ISIN' : ['I1', 'I2', 'I3', 'I4', 'I5']
    })
df2 = pd.DataFrame({
        'Value': [100, 200, 300],
        'ISIN' : ['I2', 'I3', 'I5']
    })

df3 = pd.merge(df1, df2)[['Security', 'Value']]
print(df3)

# %%
corona0622_doc = pd.merge(corona0622,doc2018)
corona0622_doc.head()
# Out:
#       국가 ISO3 치명(%)  완치(%)     발생률        인구수    확진자_합계    확진자1일     치료중_합계  \
# 0   미국🇺🇸  USA   1.8   83.6  104032  331002651  34419981  13922.0  5034090.0
# 1  프랑스🇫🇷  FRA   1.9   96.7   88244   65273511   5757798    487.0    80626.0
# 2   터키🇹🇷  TUR   0.9   97.4   63811   84339067   5375593   5294.0    88626.0
# 3  러시아🇷🇺  RUS   2.4   91.4   36787  145934462   5350919  16715.0   331122.0
# 4   영국🇬🇧  GBR   2.8   92.7   68526   67886011   4640507  10467.0   208530.0
#
#      치료중1일  ...  사망자1일        완치합계     완치1일   INDICATOR  SUBJECT  MEASURE  \
# 0 -43487.0  ...  317.0  28768408.0  57092.0  MEDICALDOC      TOT  1000HAB
# 1  -9361.0  ...   40.0   5566394.0   9808.0  MEDICALDOC      TOT  1000HAB
# 2    150.0  ...   51.0   5237731.0   5093.0  MEDICALDOC      TOT  1000HAB
# 3   5052.0  ...  546.0   4889450.0  11117.0  MEDICALDOC      TOT  1000HAB
# 4   8451.0  ...    5.0   4303996.0   2011.0  MEDICALDOC      TOT  1000HAB
#
#   FREQUENCY  TIME Value Flag Codes
# ...

# %%
corona0622_doc.rename(columns={'Value':'Doctors per 1000'},inplace=True)
corona0622_doc.drop(["INDICATOR","SUBJECT","MEASURE","FREQUENCY","TIME","Flag Codes"],axis=1,inplace=True)
corona0622_doc.columns
# Out:
# Index(['국가', 'ISO3', '치명(%)', '완치(%)', '발생률', '인구수', '확진자_합계', '확진자1일',
#        '치료중_합계', '치료중1일', '위중증_합계', '위중증1일', '사망자합계', '사망자1일', '완치합계', '완치1일',
#        'Doctors per 1000'],
#       dtype='object')

# %% [markdown]
# #### merge로 CPI와 결합.... 여러분 데이터 클랜징과 준비는 그냥 엑셀에서 합시다. 솔직히 데이터 클랜징은 판다스가 엑셀만 못하다. 엑셀로 했으면 10분이면 끝날듯. 애초에 하나씩 타이핑해서 명령어를 내려야 한다는 점과 데이터 상황을 GUI UI로 실시간으로 보는게 아니라 내가 계속 호출해야한다는 것부터가 병맛이다. 빌게이츠가 괜히 돈을 쳐받은게 아니네

# %%
cpi = pd.merge(corona0622,CPI)
cpi.head()
# Out:
#       국가 ISO3 치명(%)  완치(%)     발생률         인구수    확진자_합계    확진자1일     치료중_합계  \
# 0   미국🇺🇸  USA   1.8   83.6  104032   331002651  34419981  13922.0  5034090.0
# 1   인도🇮🇳  IND   1.3   96.5   21760  1380004385  30002691  37399.0   662304.0
# 2  브라질🇧🇷  BRA   2.8   90.6   84949   212559417  17969806  41878.0  1178597.0
# 3  프랑스🇫🇷  FRA   1.9   96.7   88244    65273511   5757798    487.0    80626.0
# 4   터키🇹🇷  TUR   0.9   97.4   63811    84339067   5375593   5294.0    88626.0
#
#      치료중1일  위중증_합계  위중증1일   사망자합계  사망자1일        완치합계     완치1일  \
# 0 -43487.0  3939.0  -18.0  617483  317.0  28768408.0  57092.0
# 1 -18984.0  8944.0    NaN  389661  833.0  28950726.0  55550.0
# 2 -27175.0  8318.0    NaN  502817  899.0  16288392.0  68154.0
# 3  -9361.0  1655.0  -48.0  110778   40.0   5566394.0   9808.0
# 4    150.0   808.0   -5.0   49236   51.0   5237731.0   5093.0
#
#                     Country CPI score 2020
# 0  United States of America             67
# ...

# %%
#그와중에 미국 cpi 스코어 보솤ㅋㅋ 67ㅋㅋㅋ
len(cpi)
# Out:
# 178

# %% [markdown]
# ## 저장

# %%
cpi.to_csv("covid19_cpi.csv",index=False)
os.listdir( os.getcwd() )
# Out:
# ['.ipynb_checkpoints',
#  '0623.zip',
#  'API_SH.MED.PHYS.ZS_DS2_en_csv_v2_2447407',
#  'API_SH.MED.PHYS.ZS_DS2_en_csv_v2_2447407.zip',
#  'coronaboard_0622_today.csv',
#  'coronaboard_0622_today.xlsx',
#  'coronaboard_0622_today_top10.csv',
#  'coronaboard_0622_today_top10.xlsx',
#  'coronaboard_0622_yesterday.csv',
#  'coronaboard_0622_yesterday.xlsx',
#  'coronaboard_0622_yesterday_top10.csv',
#  'coronaboard_0622_yesterday_top10.xlsx',
#  'coronaboard_0623_today.csv',
#  'coronaboard_0623_today.xlsx',
#  'coronaboard_0623_today_top10.csv',
#  'coronaboard_0623_today_top10.xlsx',
#  'coronaboard_0623_yesterday.csv',
#  'coronaboard_0623_yesterday.xlsx',
#  'coronaboard_0623_yesterday_top10.csv',
#  'coronaboard_0623_yesterday_top10.xlsx',
#  'covid19_cpi.csv',
#  'CPI2020_GlobalTablesTS_210125.csv',
#  'CPI2020_GlobalTablesTS_210125.xlsx',
#  'OECD_num_of_doctors_per1000.csv',
#  'OECD_num_of_nurses_per1000.csv',
#  'test.html',
#  'treemap_covid19_world_cases.html',
# ...

# %% [markdown]
# ## 기타 코드들

# %%
#docs 리스트에 있는 나라들만 필터링
corona0622_docs = corona0622[corona0622['ISO3'].isin(doc2018["ISO3"])]
corona0622_docs.head()
# Out:
#       국가 ISO3 치명(%)  완치(%)     발생률        인구수    확진자_합계    확진자1일     치료중_합계  \
# 0   미국🇺🇸  USA   1.8   83.6  104032  331002651  34419981  13922.0  5034090.0
# 3  프랑스🇫🇷  FRA   1.9   96.7   88244   65273511   5757798    487.0    80626.0
# 4   터키🇹🇷  TUR   0.9   97.4   63811   84339067   5375593   5294.0    88626.0
# 5  러시아🇷🇺  RUS   2.4   91.4   36787  145934462   5350919  16715.0   331122.0
# 6   영국🇬🇧  GBR   2.8   92.7   68526   67886011   4640507  10467.0   208530.0
#
#      치료중1일  위중증_합계  위중증1일   사망자합계  사망자1일        완치합계     완치1일
# 0 -43487.0  3939.0  -18.0  617483  317.0  28768408.0  57092.0
# 3  -9361.0  1655.0  -48.0  110778   40.0   5566394.0   9808.0
# 4    150.0   808.0   -5.0   49236   51.0   5237731.0   5093.0
# 5   5052.0  2300.0    NaN  130347  546.0   4889450.0  11117.0
# 6   8451.0   223.0   13.0  127981    5.0   4303996.0   2011.0

# %%
corona0622_docs["1000명당 의사 수"]=doc2018["Value"].values

# %%
corona0622_docs.head()
# Out:
#       국가 iso3 치명(%)  완치(%)     발생률        인구수    확진자_합계    확진자1일     치료중_합계  \
# 0   미국🇺🇸  USA   1.8   83.6  104032  331002651  34419981  13922.0  5034090.0
# 3  프랑스🇫🇷  FRA   1.9   96.7   88244   65273511   5757798    487.0    80626.0
# 4   터키🇹🇷  TUR   0.9   97.4   63811   84339067   5375593   5294.0    88626.0
# 5  러시아🇷🇺  RUS   2.4   91.4   36787  145934462   5350919  16715.0   331122.0
# 6   영국🇬🇧  GBR   2.8   92.7   68526   67886011   4640507  10467.0   208530.0
#
#      치료중1일  위중증_합계  위중증1일   사망자합계  사망자1일        완치합계     완치1일  1000명당 의사 수
# 0 -43487.0  3939.0  -18.0  617483  317.0  28768408.0  57092.0         3.75
# 3  -9361.0  1655.0  -48.0  110778   40.0   5566394.0   9808.0         5.24
# 4    150.0   808.0   -5.0   49236   51.0   5237731.0   5093.0         3.13
# 5   5052.0  2300.0    NaN  130347  546.0   4889450.0  11117.0         2.78
# 6   8451.0   223.0   13.0  127981    5.0   4303996.0   2011.0         4.04

# %%
#CPI 리스트에 있는 나라 필터링
corona0622_cpi = corona0622[corona0622['iso3'].isin(CPI["ISO3"])]
len(corona0622_cpi)
# Out:
# 178
